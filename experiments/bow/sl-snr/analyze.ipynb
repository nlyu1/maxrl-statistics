# %%
from src import get_repo_base
from src.experiments.bag_of_words.analysis import BagOfWordsAnalysisConfig

repo_root = get_repo_base()
STUDY_BASE = repo_root / 'artifacts' / 'bow-sl-snr-sweep'

SNR_LIST = [
    0.010, 0.011, 0.013, 0.014, 0.016, 0.018, 0.020, 0.023, 0.026, 0.029,
    0.033, 0.037, 0.041, 0.046, 0.052, 0.059, 0.066, 0.074, 0.084, 0.094,
    0.106, 0.119, 0.134, 0.151, 0.170, 0.191, 0.215, 0.242, 0.273, 0.307,
    0.346, 0.389, 0.438, 0.492, 0.554, 0.624, 0.702, 0.790, 0.889, 1.000,
]

# %%
studies = {
    f'snr_{snr:.3f}': STUDY_BASE / f'7-words_snr-{snr}_len-128_pow-0.0_ar-0.5'
    for snr in SNR_LIST
}
analysis = BagOfWordsAnalysisConfig.from_studies(studies)
print(f'{len(analysis.studies)}/{len(SNR_LIST)} experiments completed')
analysis.get_metric_dataframe()
# Out:
# 40/40 experiments completed
# shape: (400, 14)
# ┌───────────┬───────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ study     ┆ epoch ┆ train_corr ┆ train_unca ┆ … ┆ val_beta_t ┆ val_corr_ ┆ val_uncal ┆ val_beta_ │
# │ ---       ┆ ---   ┆ _target    ┆ librated_r ┆   ┆ arget      ┆ ground_tr ┆ ibrated_r ┆ ground_tr │
# │ str       ┆ i64   ┆ ---        ┆ sq_target  ┆   ┆ ---        ┆ uth       ┆ sq_ground ┆ uth       │
# │           ┆       ┆ f64        ┆ ---        ┆   ┆ f64        ┆ ---       ┆ _tr…      ┆ ---       │
# │           ┆       ┆            ┆ f64        ┆   ┆            ┆ f64       ┆ ---       ┆ f64       │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ f64       ┆           │
# ╞═══════════╪═══════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ snr_0.010 ┆ 0     ┆ -0.001649  ┆ -0.006463  ┆ … ┆ 0.005285   ┆ 0.13874   ┆ -50.21565 ┆ 0.019199  │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ 2         ┆           │
# │ snr_0.010 ┆ 1     ┆ 0.006392   ┆ -0.007543  ┆ … ┆ 0.074826   ┆ 0.107825  ┆ -39.67480 ┆ 0.016828  │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆           │
# │ snr_0.010 ┆ 2     ┆ 0.019239   ┆ -0.005915  ┆ … ┆ 0.171383   ┆ 0.182547  ┆ -25.63716 ┆ 0.034776  │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ 9         ┆           │
# │ snr_0.010 ┆ 3     ┆ 0.018517   ┆ -0.00659   ┆ … ┆ -0.016492  ┆ 0.110055  ┆ -93.44459 ┆ 0.011256  │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ 5         ┆           │
# │ snr_0.010 ┆ 4     ┆ 0.02622    ┆ -0.004356  ┆ … ┆ 0.013637   ┆ 0.096014  ┆ -51.32661 ┆ 0.013223  │
# │           ┆       ┆            ┆            ┆   ┆            ┆           ┆ 1         ┆           │
# │ …         ┆ …     ┆ …          ┆ …          ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ snr_1.000 ┆ 5     ┆ 0.517115   ┆ 0.261916   ┆ … ┆ 1.170268   ┆ 0.728766  ┆ 0.519868  ┆ 1.170164  │
# │ snr_1.000 ┆ 6     ┆ 0.522096   ┆ 0.266843   ┆ … ┆ 1.124353   ┆ 0.721148  ┆ 0.51392   ┆ 1.121841  │
# │ snr_1.000 ┆ 7     ┆ 0.526638   ┆ 0.271676   ┆ … ┆ 1.154813   ┆ 0.737345  ┆ 0.533753  ┆ 1.156219  │
# │ snr_1.000 ┆ 8     ┆ 0.530795   ┆ 0.276061   ┆ … ┆ 1.143936   ┆ 0.741923  ┆ 0.541565  ┆ 1.145543  │
# │ snr_1.000 ┆ 9     ┆ 0.533299   ┆ 0.279363   ┆ … ┆ 1.147853   ┆ 0.746873  ┆ 0.548604  ┆ 1.14749   │
# └───────────┴───────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
analysis.xy_plots([
    # Total v. signal fitting
    # ('train_uncalibrated_rsq_target', 'train_uncalibrated_rsq_ground_truth'),
    # ('train_uncalibrated_rsq_target', 'train_corr_ground_truth'),
    ('train_corr_target', 'train_uncalibrated_rsq_ground_truth'),
    ('train_corr_target', 'train_corr_ground_truth'),
    # Train-total v. val-signal fitting
    ('train_corr_target', 'val_uncalibrated_rsq_ground_truth'),
    # ('train_corr_target', 'val_corr_ground_truth'),
    # Betas
    # ('train_corr_target', 'train_beta_ground_truth'),
    # ('train_corr_target', 'val_beta_ground_truth'),
])
